# %%
import pandas as pd
import json
from pathlib import Path

# %%
# Load dataset from local JSON file
data_file = Path("historical_aqi_weather_data.json")

if not data_file.exists():
    raise FileNotFoundError(f"Data file not found: {data_file}. Please ensure historical_aqi_weather_data.json exists in the project root.")

# Load the JSON file
with open(data_file, 'r') as f:
    data = json.load(f)

# Now 'data' contains your JSON data
print(f" Loaded data from {data_file}")
print(f"   Records: {len(data)}" if isinstance(data, list) else "   Loaded JSON data")
# Out:
# ✅ Loaded data from historical_aqi_weather_data.json
#    Records: 4343

# %%
import json
import pandas as pd

# # Load JSON file
# with open('./historical_aqi_weather_data.json', 'r') as f:
#     data = json.load(f)

records = []

for item in data:
    weather_data = item['weather']
    aqi_info = item['aqi']
    aqi_list = aqi_info['list']

    if aqi_list:  # AQI data is available
        aqi_data = aqi_list[0]
        components = aqi_data['components']
        record = {
            'aqi_index': aqi_data['main']['aqi'],
            'aqi_timestamp': aqi_data['dt'],
            'co': components['co'],
            'no': components['no'],
            'no2': components['no2'],
            'o3': components['o3'],
            'so2': components['so2'],
            'pm2_5': components['pm2_5'],
            'pm10': components['pm10'],
            'nh3': components['nh3']
        }
    else:  # AQI data is missing
        record = {
            'aqi_index': None,
            'aqi_timestamp': None,
            'co': None,
            'no': None,
            'no2': None,
            'o3': None,
            'so2': None,
            'pm2_5': None,
            'pm10': None,
            'nh3': None,
        }

    # Add weather data
    record.update({
        'temperature_2m': weather_data['temperature_2m'],
        'relative_humidity_2m': weather_data['relative_humidity_2m'],
        'precipitation': weather_data['precipitation'],
        'wind_speed_10m': weather_data['wind_speed_10m'],
        'wind_direction_10m': weather_data['wind_direction_10m'],
        'surface_pressure': weather_data['surface_pressure'],
        'dew_point_2m': weather_data['dew_point_2m'],
        'apparent_temperature': weather_data['apparent_temperature'],
        'shortwave_radiation': weather_data['shortwave_radiation'],
        'et0_fao_evapotranspiration': weather_data['et0_fao_evapotranspiration'],
    })

    records.append(record)

# Convert to DataFrame
df = pd.DataFrame(records)

# %%
import datetime
# Convert 'aqi_timestamp' to datetime and extract individual components
df['year'] = df['aqi_timestamp'].apply(lambda x: datetime.datetime.utcfromtimestamp(x).year if pd.notna(x) else None)
df['month'] = df['aqi_timestamp'].apply(lambda x: datetime.datetime.utcfromtimestamp(x).month if pd.notna(x) else None)
df['day'] = df['aqi_timestamp'].apply(lambda x: datetime.datetime.utcfromtimestamp(x).day if pd.notna(x) else None)
df['hour'] = df['aqi_timestamp'].apply(lambda x: datetime.datetime.utcfromtimestamp(x).hour if pd.notna(x) else None)

# Print the result
print(df[['year', 'month', 'day', 'hour']].head())
# Print the result

df.drop(columns=['aqi_timestamp'], inplace=True)
print(df.head())
# Out:
#      year  month   day  hour
# 0  2024.0   10.0  22.0  19.0
# 1  2024.0   10.0  22.0  20.0
# 2  2024.0   10.0  22.0  21.0
# 3  2024.0   10.0  22.0  22.0
# 4  2024.0   10.0  22.0  23.0
#    aqi_index       co    no    no2     o3    so2  pm2_5    pm10    nh3  \
# 0        4.0  1201.63  0.01  45.24  41.13   8.82  68.43  112.67  11.78
# 1        4.0  1388.55  0.05  57.58  26.46   8.94  71.22  113.28  10.39
# 2        5.0  1468.66  0.06  58.26  21.99  10.01  76.47  117.74  10.64
# 3        5.0  1375.20  0.01  48.67  26.82  10.73  79.89  121.13  11.02
# 4        4.0  1001.36  0.00  30.85  43.99   8.82  72.51  111.48   8.87
#
#    temperature_2m  ...  wind_direction_10m  surface_pressure  dew_point_2m  \
# 0            27.3  ...               314.0            1011.3          23.8
# 1            26.8  ...               307.0            1011.2          24.0
# 2            26.2  ...               323.0            1011.0          24.4
# 3            26.0  ...               331.0            1010.9          24.9
# 4            26.0  ...               322.0            1011.0          24.9
#
#    apparent_temperature  shortwave_radiation  et0_fao_evapotranspiration  \
# 0                  31.5                  0.0                        0.03
# 1                  30.9                  0.0                        0.02
# 2                  30.3                  0.0                        0.02
# 3                  30.5                  0.0                        0.00
# 4                  30.6                  0.0                        0.00
#
#      year  month   day  hour
# 0  2024.0   10.0  22.0  19.0
# 1  2024.0   10.0  22.0  20.0
# 2  2024.0   10.0  22.0  21.0
# 3  2024.0   10.0  22.0  22.0
# 4  2024.0   10.0  22.0  23.0
#
# [5 rows x 23 columns]
# C:\Users\Saadan\AppData\Local\Temp\ipykernel_12200\2175991795.py:3: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   df['year'] = df['aqi_timestamp'].apply(lambda x: datetime.datetime.utcfromtimestamp(x).year if pd.notna(x) else None)
# C:\Users\Saadan\AppData\Local\Temp\ipykernel_12200\2175991795.py:4: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   df['month'] = df['aqi_timestamp'].apply(lambda x: datetime.datetime.utcfromtimestamp(x).month if pd.notna(x) else None)
# C:\Users\Saadan\AppData\Local\Temp\ipykernel_12200\2175991795.py:5: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   df['day'] = df['aqi_timestamp'].apply(lambda x: datetime.datetime.utcfromtimestamp(x).day if pd.notna(x) else None)
# C:\Users\Saadan\AppData\Local\Temp\ipykernel_12200\2175991795.py:6: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   df['hour'] = df['aqi_timestamp'].apply(lambda x: datetime.datetime.utcfromtimestamp(x).hour if pd.notna(x) else None)

# %%
# Save to CSV
df.to_csv('aqi_weather_data.csv', index=False)
print("CSV file created: aqi_weather_data.csv")
# Out:
# CSV file created: aqi_weather_data.csv

# %%
print(df)
# Out:
#       aqi_index       co    no    no2      o3    so2  pm2_5    pm10    nh3  \
# 0           4.0  1201.63  0.01  45.24   41.13   8.82  68.43  112.67  11.78
# 1           4.0  1388.55  0.05  57.58   26.46   8.94  71.22  113.28  10.39
# 2           5.0  1468.66  0.06  58.26   21.99  10.01  76.47  117.74  10.64
# 3           5.0  1375.20  0.01  48.67   26.82  10.73  79.89  121.13  11.02
# 4           4.0  1001.36  0.00  30.85   43.99   8.82  72.51  111.48   8.87
# ...         ...      ...   ...    ...     ...    ...    ...     ...    ...
# 4338        4.0   113.97  0.01   0.07   68.93   0.48  44.69  162.71   0.00
# 4339        4.0   109.04  0.01   0.06   67.06   0.27  44.82  155.90   0.00
# 4340        3.0   104.97  0.00   0.09  108.56   0.43  19.13   43.54   0.05
# 4341        3.0   104.97  0.00   0.09  108.56   0.43  19.13   43.54   0.05
# 4342        3.0    97.34  0.00   0.07  103.31   0.27  20.87   63.76   0.01
#
#       temperature_2m  ...  wind_direction_10m  surface_pressure  dew_point_2m  \
# 0               27.3  ...               314.0            1011.3          23.8
# 1               26.8  ...               307.0            1011.2          24.0
# 2               26.2  ...               323.0            1011.0          24.4
# 3               26.0  ...               331.0            1010.9          24.9
# 4               26.0  ...               322.0            1011.0          24.9
# ...              ...  ...                 ...               ...           ...
# 4338            26.2  ...               275.0            1003.9          23.1
# 4339            34.8  ...               247.0            1004.6          23.1
# 4340            23.6  ...               321.0            1014.2          17.1
# 4341            23.6  ...               321.0            1014.2          17.1
# 4342            25.1  ...               248.0            1014.2          17.3
#
#       apparent_temperature  shortwave_radiation  et0_fao_evapotranspiration  \
# 0                     31.5                  0.0                        0.03
# 1                     30.9                  0.0                        0.02
# 2                     30.3                  0.0                        0.02
# 3                     30.5                  0.0                        0.00
# 4                     30.6                  0.0                        0.00
# ...                    ...                  ...                         ...
# 4338                  31.1                  0.0                        0.00
# 4339                  38.8                847.0                        0.72
# 4340                  25.4                  0.0                        0.01
# 4341                  25.4                  0.0                        0.01
# 4342                  26.6                  0.0                        0.04
#
#         year  month   day  hour
# 0     2024.0   10.0  22.0  19.0
# 1     2024.0   10.0  22.0  20.0
# 2     2024.0   10.0  22.0  21.0
# 3     2024.0   10.0  22.0  22.0
# 4     2024.0   10.0  22.0  23.0
# ...      ...    ...   ...   ...
# 4338  2025.0    4.0  26.0  11.0
# 4339  2025.0    4.0  27.0  10.0
# 4340  2025.0   11.0   7.0  20.0
# 4341  2025.0   11.0   7.0  20.0
# 4342  2025.0   11.0   8.0  14.0
#
# [4343 rows x 23 columns]

# %%
# Save the CSV file locally (already saved in cell 4, but confirm here)
csv_path = Path("aqi_weather_data.csv")
if csv_path.exists():
    print(f" CSV file already saved to: {csv_path}")
    print(f"   File size: {csv_path.stat().st_size / 1024:.2f} KB")
    print(f"   Records: {len(df)}")
else:
    # If for some reason it wasn't saved, save it now
    df.to_csv(csv_path, index=False)
    print(f" CSV file saved to: {csv_path}")
# Out:
# ✅ CSV file already saved to: aqi_weather_data.csv
#    File size: 512.09 KB
#    Records: 4343

# %%
# Note: This notebook creates 'aqi_weather_data.csv' (raw data)
# The cleaned dataset 'cleaned_aqi_weather_dataset.csv' is created in EDA.ipynb
# Feast will be automatically updated when the cleaned dataset is saved in EDA.ipynb
print("\n Tip: After running EDA.ipynb to create cleaned_aqi_weather_dataset.csv,")
print("   Feast feature store will be automatically updated.")
